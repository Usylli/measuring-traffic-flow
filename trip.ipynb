# %%
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import psycopg2
import plotly.graph_objects as go
import plotly.express as px
px.set_mapbox_access_token('pk.eyJ1IjoidXN5bGxpIiwiYSI6ImNsZ2ppa3NlaDAyejIzc3FxcDV3ZXFrdW0ifQ.8mDXepFhm39ABr8ElTxDDQ')
import os
import plotly.graph_objs as go
token = 'pk.eyJ1IjoidXN5bGxpIiwiYSI6ImNsZ2ppa3NlaDAyejIzc3FxcDV3ZXFrdW0ifQ.8mDXepFhm39ABr8ElTxDDQ'

# %%
conn = psycopg2.connect(
    host="127.0.0.1",
    database="devdb",
    user="devuser",
    password="123456"
)

query = """
    SELECT guid, datetime, latitude, longitude
    FROM cars_carslocation
    WHERE guid = '403674413556996000' and DATE(datetime) = '2020-12-13'
    ORDER BY guid, datetime
"""

df = pd.read_sql_query(query, conn)
conn.close()
df['latitude'] = df['latitude'].astype(float)
df['longitude'] = df['longitude'].astype(float)
df
# Out:
# C:\Users\usyll\AppData\Local\Temp\ipykernel_5452\1344530352.py:15: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#                    guid                  datetime   latitude  longitude
# 0    403674413556996000 2020-12-13 03:41:00+00:00  51.090143  71.402945
# 1    403674413556996000 2020-12-13 03:41:00+00:00  51.086435  71.401557
# 2    403674413556996000 2020-12-13 03:41:00+00:00  51.091381  71.403322
# 3    403674413556996000 2020-12-13 03:41:00+00:00  51.091381  71.403322
# 4    403674413556996000 2020-12-13 03:41:00+00:00  51.090143  71.402945
# ..                  ...                       ...        ...        ...
# 131  403674413556996000 2020-12-13 17:48:00+00:00  51.095524  71.427016
# 132  403674413556996000 2020-12-13 17:48:00+00:00  51.095524  71.427016
# ...

# %%
fig = go.Figure(go.Scattermapbox(
    mode = "markers+text+lines",
    lon = df['longitude'], lat = df['latitude'],
    marker = {'size': 20, 'symbol': ["bus"]},
    text = ["Bus"],textposition = "bottom right"))

fig.update_layout(
    mapbox = {
        'accesstoken': token,
        'style': "outdoors", 'zoom': 10},
    showlegend = False)

fig.show()
# Out:
# <div>                            <div id="b075379d-04b0-4e79-8455-09e7d2810db5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b075379d-04b0-4e79-8455-09e7d2810db5")) {                    Plotly.newPlot(                        "b075379d-04b0-4e79-8455-09e7d2810db5",                        [{"lat":[51.09014257,51.08643451,51.09138149,51.09138149,51.09014257,51.09454692,51.09454692,51.11170061,51.11044691,51.10727922,51.10727922,51.12139134,51.11170061,51.10736624,51.10736624,51.08877902,51.08962486,51.08962486,51.08877902,51.08643451,51.06792961,51.05940856,51.05508662,51.04206177,51.04206177,51.04862495,51.04862495,51.05506043,51.06750908,51.07922328,51.07922328,51.08399606,51.08399606,51.09453567,51.09453567,51.11421137,51.11421137,51.11046635,51.
# ...

# %%
fig = px.scatter_mapbox(df, lat="latitude", lon="longitude")

fig.show()
# Out:
# <div>                            <div id="3888e8c1-1b5e-4aeb-8820-7f202d2f3d25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3888e8c1-1b5e-4aeb-8820-7f202d2f3d25")) {                    Plotly.newPlot(                        "3888e8c1-1b5e-4aeb-8820-7f202d2f3d25",                        [{"hovertemplate":"latitude=%{lat}<br>longitude=%{lon}<extra></extra>","lat":[51.09014257,51.08643451,51.09138149,51.09138149,51.09014257,51.09454692,51.09454692,51.11170061,51.11044691,51.10727922,51.10727922,51.12139134,51.11170061,51.10736624,51.10736624,51.08877902,51.08962486,51.08962486,51.08877902,51.08643451,51.06792961,51.05940856,51.05508662,51.04206177,51.04206177,51.04862495,51.04862495,51.05506043,51.06750908,51.07922328,51.07922328,51.08399606,51.083
# ...

# %%
df = px.data.carshare()
fig = px.scatter_mapbox(df, lat="centroid_lat", lon="centroid_lon",     color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)
fig.show()
# Out:
#      centroid_lat  centroid_lon    car_hours  peak_hour
# 0       45.471549    -73.588684  1772.750000          2
# 1       45.543865    -73.562456   986.333333         23
# 2       45.487640    -73.642767   354.750000         20
# 3       45.522870    -73.595677   560.166667         23
# 4       45.453971    -73.738946  2836.666667         19
# ..            ...           ...          ...        ...
# 244     45.547171    -73.556258   951.416667          3
# 245     45.546482    -73.574939   795.416667          2
# 246     45.495523    -73.627725   425.750000          8
# 247     45.521199    -73.581789  1044.833333         17
# 248     45.532564    -73.567535   694.916667          5
#
# [249 rows x 4 columns]
